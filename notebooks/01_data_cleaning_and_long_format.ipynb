# %% [markdown]
# # 01 Data cleaning and long format
#
# This notebook runs `src/create_long_dataset.py`, creates the long-format dataset, and displays the main validation checks and descriptive tables.
#
# Before running it, put the raw Qualtrics CSV in `data/raw/`. The raw data folder is ignored by Git.

# %%
from pathlib import Path
import sys

import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

PROJECT_ROOT

# %% [markdown]
# ## Run the cleaning script
#
# This cell prints the validation checks from the script and returns the long-format dataframe.

# %%
import create_long_dataset

long_data = create_long_dataset.main()
long_data.head()

# %% [markdown]
# ## Basic checks

# %%
print(f"Rows: {len(long_data)}")
print(f"Participants: {long_data['participant_id'].nunique()}")
print(f"Items: {sorted(long_data['item_id'].unique())}")

long_data.groupby('participant_id').size().value_counts().sort_index()

# %%
long_data[['trust_score', 'reliance_score', 'confidence_change']].describe()

# %% [markdown]
# ## Descriptive tables

# %%
tables_dir = PROJECT_ROOT / "outputs" / "tables"

condition_counts = pd.read_csv(tables_dir / "condition_counts.csv")
descriptive_by_condition = pd.read_csv(tables_dir / "descriptive_by_condition.csv")
descriptive_by_item_condition = pd.read_csv(tables_dir / "descriptive_by_item_condition.csv")

condition_counts

# %%
descriptive_by_condition

# %%
descriptive_by_item_condition
